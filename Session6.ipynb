# %% [markdown]
# # Session 6 – User Input and While Loops
# Learn how to accept user input with `input()` and control program flow with `while` loops.

# %%
# 1. Accepting User Input

# %%
# 2. Writing Clear Prompts

# %%
# 3. Using int() for Numerical Input

# %%
# 4. The Modulo Operator (%)

# %%
# 5. Using While Loops

# %%
# 6. Quitting with User Input

# %%
# 7. Using a Flag

# %%
# 8. Using break to Exit a Loop

# %%
# 9. Using continue in a While Loop

# %%
# 10. Moving Items from One List to Another

# %%
# 11. Removing All Instances of a Value from a List

# %%
# 12. Filling a Dictionary with User Input

# %% [markdown]
# ## Lab Exercises

# %% [markdown]
# 1. Pizza Toppings: Prompt the user to enter pizza toppings until they enter 'quit'.

# %% [markdown]
# 2. Movie Tickets: Determine the cost of a ticket based on the user's age.

# %% [markdown]
# 3. Dream Vacation: Ask users about their dream vacation and display the responses.
